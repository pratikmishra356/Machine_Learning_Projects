# %%
import tensorflow as tf

# %%
import keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sns

# %%
data = pd.read_csv("/Users/pratikmishra/Downloads/diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
columns = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
for col in columns:
    data[col].replace(0, np.NaN, inplace=True)

#for col in columns:
data.fillna(data.mean(),inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null float64
# BloodPressure               768 non-null float64
# SkinThickness               768 non-null float64
# Insulin                     768 non-null float64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
data.shape
# Out:
# (768, 9)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0       35.00000  155.548223  33.6
# 1            1     85.0           66.0       29.00000  155.548223  26.6
# 2            8    183.0           64.0       29.15342  155.548223  23.3
# 3            1     89.0           66.0       23.00000   94.000000  28.1
# 4            0    137.0           40.0       35.00000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.435949      12.096346       8.790942   85.021108
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      25.000000  121.500000
# 50%       3.000000  117.000000      72.202592      29.153420  155.548223
# 75%       6.000000  140.250000      80.000000      32.000000  155.548223
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.875151                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.400000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
data1 = data.values
X = data1[:,0:8]
Y = data1[:,8].astype(int)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit_transform(X)
#X_scaled = scaler.transform(X)
data = pd.DataFrame(scaler)

# %%
data.columns = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']

# %%
data.describe()
# Out:
#         Pregnancies       Glucose  BloodPressure  SkinThickness       Insulin  \
# count  7.680000e+02  7.680000e+02   7.680000e+02   7.680000e+02  7.680000e+02
# mean   2.544261e-17 -3.301757e-16   6.966722e-16   6.866252e-16 -2.352033e-16
# std    1.000652e+00  1.000652e+00   1.000652e+00   1.000652e+00  1.000652e+00
# min   -1.141852e+00 -2.554131e+00  -4.004245e+00  -2.521670e+00 -1.665945e+00
# 25%   -8.448851e-01 -7.212214e-01  -6.953060e-01  -4.727737e-01 -4.007289e-01
# 50%   -2.509521e-01 -1.540881e-01  -1.675912e-02   8.087936e-16 -3.345079e-16
# 75%    6.399473e-01  6.103090e-01   6.282695e-01   3.240194e-01 -3.345079e-16
# max    3.906578e+00  2.541850e+00   4.102655e+00   7.950467e+00  8.126238e+00
#
#                 BMI  DiabetesPedigreeFunction           Age
# count  7.680000e+02              7.680000e+02  7.680000e+02
# mean   3.090699e-16              2.398978e-16  1.857600e-16
# std    1.000652e+00              1.000652e+00  1.000652e+00
# min   -2.075119e+00             -1.189553e+00 -1.041549e+00
# 25%   -7.215397e-01             -6.889685e-01 -7.862862e-01
# 50%   -8.363615e-03             -3.001282e-01 -3.608474e-01
# 75%    6.029301e-01              4.662269e-01  6.602056e-01
# max    5.042087e+00              5.883565e+00  4.063716e+00

# %%
data_res=pd.DataFrame(Y)
data_res.columns=["Outcome"]
data_res.head()
# Out:
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %%
from sklearn.model_selection import GridSearchCV,KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam

# %%
def create_model():
    model = Sequential()
    
    model.add(Dense(8,input_dim=8,kernel_initializer='normal',activation='relu'))
    model.add(Dense(4,input_dim=8,kernel_initializer='normal',activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    
    
    adam = Adam(lr=0.01)
    
    model.compile(loss='binary_crossentropy',optimizer=adam,metrics=['accuracy'])
    
    return model

model = create_model()
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
seed = 5
np.random.seed(seed)


def create_model():
    model = Sequential()
    
    model.add(Dense(8,input_dim=8,kernel_initializer='normal',activation='relu'))
    model.add(Dense(4,input_dim=8,kernel_initializer='normal',activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    
    
    adam = Adam(lr=0.01)
    
    model.compile(loss='binary_crossentropy',optimizer=adam,metrics=['accuracy'])
    
    return model

model = KerasClassifier(build_fn=create_model, verbose=0)

batch_size = [20]
epochs = [10]


param_grid = dict(batch_size=batch_size,epochs=epochs)

grid = GridSearchCV(estimator=model,param_grid=param_grid, cv=KFold(random_state=seed), verbose=10)

grid_result = grid.fit(scaler,Y)

print("Best: {}, using {}".format(grid_result.best_score_,grid_result.best_params_))

means = grid_result.cv_results_["mean_test_score"]
std = grid_result.cv_results_["std_test_score"]
params = grid_result.cv_results_["params"]

for mean,stdev,param in zip(means,std,params):
    print("{} ({}) with {}".format(mean,stdev,param))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.747, total=   8.6s
# [CV] batch_size=20, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.6s remaining:    0.0s
# [CV] ............ batch_size=20, epochs=10, score=0.714, total=   9.4s
# [CV] batch_size=20, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   18.0s remaining:    0.0s
# [CV] ............ batch_size=20, epochs=10, score=0.799, total=   8.7s
# [CV] batch_size=20, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   26.7s remaining:    0.0s
# [CV] ............ batch_size=20, epochs=10, score=0.837, total=   9.8s
# [CV] batch_size=20, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   36.5s remaining:    0.0s
# [CV] ............ batch_size=20, epochs=10, score=0.752, total=   9.8s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   46.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   46.2s finished
# Best: 0.7695951107756288, using {'batch_size': 20, 'epochs': 10}
# 0.7695951107756288 (0.04298949121029072) with {'batch_size': 20, 'epochs': 10}
